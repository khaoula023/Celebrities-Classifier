# %%
! pip install bing-image-downloader

# %%
# !mkdir dataset

# %%
from bing_image_downloader import downloader
downloader.download("Ramy Youssef", limit=150,  output_dir='dataset')
# Out:
# [%] Downloading Images to /content/dataset/Ramy Youssef
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://media1.popsugar-assets.com/files/thumbor/VdbVJIbU9FAEEH50qfTQ4K3xunA/fit-in/2048xorig/filters:format_auto-!!-:strip_icc-!!-/2020/09/20/084/n/1922283/tmp_QFZme7_6fe0d41009fe0a5d_GettyImages-1158923241.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.gqmiddleeast.com/2021/06/Ramy-Youssef-wins-at-the-Golden-Globes-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.gq.com/photos/5ea2ebcedf7bcc00099c2bc2/master/w_1600%2Cc_limit/ramy-youssef-gq-may-2020-06.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://fr.web.img6.acsta.net/pictures/20/02/14/16/25/2958867.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://media.newyorker.com/photos/6344714ec9764ceac916a4fe/master/w_2560%2Cc_limit/Battan-Ramy.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("Riyad Mahrez", limit=150,  output_dir='dataset')
# Out:
# [%] Downloading Images to /content/dataset/Riyad Mahrez
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.nottheoldfirm.com/static/uploads/15/2021/05/GettyImages-1319655021-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.90maat.com/wp-content/uploads/2019/10/fbl-eur-c1-man-city-training.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://ethnicelebs.com/wp-content/uploads/2019/07/LMK-177242-Riyad-Mahrez.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://static.independent.co.uk/s3fs-public/thumbnails/image/2018/01/31/12/riyad-mahrez-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.sportzcraazy.com/wp-content/uploads/2019/11/nintchdbpict0003633886741-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn.mos.cms.futurecdn.net/5org3TQeM7ErnmZ8jifkLo-1200-80.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("Mahira Khan", limit=150,  output_dir='dataset')
# Out:
# [%] Downloading Images to /content/dataset/Mahira Khan
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://propakistani.pk/lens/wp-content/uploads/2020/12/mahira-khan-3-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://starspie.com/wp-content/uploads/2021/06/Mahira-Khan-Image-1022x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.bollywoodbiography.in/wp-content/uploads/2017/05/Mahira-Khan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://starspie.com/wp-content/uploads/2021/06/Mahira-Khan-Photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://reviewit.pk/wp-content/uploads/2020/01/Mahira-Khan-12.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://showbizpk.com/wp-content/uploads/2020/11/mahira_khan_3.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("Han Ye-seul", limit=150,  output_dir='dataset')
# Out:
# [%] Downloading Images to /content/dataset/Han Ye-seul
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://kprofiles.com/wp-content/uploads/2019/02/han-ye-seul-1-900x750.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://photos.hancinema.net/photos/photo1197691.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/24/74/12/24741236d8f15898595bced89b09a1da.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://1739752386.rsc.cdn77.org/data/thumbs/full/70836/650/0/0/0/han-ye-seul.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://alchetron.com/cdn/han-ye-seul-ab163512-0c0d-443b-81c2-1162185c3c8-resize-750.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://iv1.lisimg.com/image/17303318/715full-ye--seul-han.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("Elyas M'Barek", limit=150,  output_dir='dataset')
# Out:
# [%] Downloading Images to /content/dataset/Elyas M'Barek
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/original/A6lFy1OxrXK5t1GwLEzVCGUU0Ak.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.stylight.net/image/upload/t_web_post_500x667/q_auto,f_auto/post-da6a692a804f621c5fe244e39a195b27eb8d61a2f8d29a5010555dfa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.promipool.de/www-promipool-de/image/upload/c_crop,h_3504,w_1984,x_183,y_0/c_fill,h_1600,w_900/q_auto:eco/f_jpg/Elyas_M_Barek_fkty4164ys
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.welt.de/img/newsticker/dpa_nt/regioline_nt/berlinbrandenburg_nt/mobile116134501/2192501197-ci102l-w1024/urn-newsml-dpa-com-20090101-130513-99-04577-large-4-3-jpg.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r dataset.zip dataset/
# Out:
#   adding: dataset/ (stored 0%)
#   adding: dataset/Riyad Mahrez/ (stored 0%)
#   adding: dataset/Riyad Mahrez/Image_73.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_63.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_144.jpg (deflated 8%)
#   adding: dataset/Riyad Mahrez/Image_21.jpg (deflated 1%)
#   adding: dataset/Riyad Mahrez/Image_107.jpg (deflated 2%)
#   adding: dataset/Riyad Mahrez/Image_7.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_137.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_67.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_83.jpg (deflated 1%)
#   adding: dataset/Riyad Mahrez/Image_46.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_79.jpg (deflated 1%)
#   adding: dataset/Riyad Mahrez/Image_97.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_124.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_54.jpg (deflated 0%)
#   adding: dataset/Riyad Mahrez/Image_18.jpg (deflated 1%)
# ...

# %%
from google.colab import files
files.download("dataset.zip")
